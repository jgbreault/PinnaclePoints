# %%
import pandas as pd
import commons as me

# %%
summitFile = f'../data/clean/summits_prm.csv'
prominenceThreshold = 500 # in m
distanceThreshold = 200*1000 # in m

summits = pd.read_csv(summitFile)

# %%
len(summits)
# Out:
# 11866676

# %%
summits = summits.query('prominence > @prominenceThreshold')

# %%
numSummits = len(summits)

candidateLinesOfSight = []
for i, observer in enumerate(summits.itertuples()):

    if i%100 == 99:
        print(f'Found {len(candidateLinesOfSight)} lines of sight candidates in {i+1}/{numSummits} summits')
    
    for target in summits.iloc[i+1:].itertuples():

        observer = me.Summit(summitId = observer.summitId,
                             latitude = observer.latitude, 
                             longitude = observer.longitude, 
                             elevation = observer.elevation, 
                             maxHorizonDistance = observer.maxHorizonDistance)
        
        target = me.Summit(summitId = target.summitId,
                           latitude = target.latitude, 
                           longitude = target.longitude, 
                           elevation = target.elevation, 
                           maxHorizonDistance = target.maxHorizonDistance)

        # TODO: Do a middle point test in batches of 100 before doing full LOS test
        
        candidateLineOfSight = me.LineOfSight(observer, target)

        # TODO: check if I have already done this summitId-summitId pair, double speed
        if :
            pass

        if lineOfSight.isInPossibleRange() and lineOfSight.getSurfaceDistance() > distanceThreshold:
            candidateLinesOfSight.append(candidateLineOfSight)
# Out:
# Potential lines of sight for 100/55444 summits processed, 0 found
# Potential lines of sight for 200/55444 summits processed, 0 found
# Potential lines of sight for 300/55444 summits processed, 0 found
# Potential lines of sight for 400/55444 summits processed, 0 found
# Potential lines of sight for 500/55444 summits processed, 0 found
# Potential lines of sight for 600/55444 summits processed, 0 found
# Potential lines of sight for 700/55444 summits processed, 0 found
# Potential lines of sight for 800/55444 summits processed, 0 found
# Potential lines of sight for 900/55444 summits processed, 0 found
# Potential lines of sight for 1000/55444 summits processed, 0 found
# Potential lines of sight for 1100/55444 summits processed, 0 found
# Potential lines of sight for 1200/55444 summits processed, 0 found
# Potential lines of sight for 1300/55444 summits processed, 0 found
# Potential lines of sight for 1400/55444 summits processed, 0 found
# ...

# %%
numCandidates = len(candidateLinesOfSight)
validatedLinesOfSight = []
for i, candidate in enumerate(candidateLinesOfSight):

    print(f'Candidate: {i+1}/{numCandidates}')
    print(f'Distance: {round(candidate.getSurfaceDistance()/1000, 1)} km')
    
    candidate.processFullLineOfSight()

    losIsValid = not candidate.isObstructed()
    if losIsValid:
        validatedLinesOfSight.append(candidate)

    print(f'Line of sight: {losIsValid}\n')
    print(f'{len(validatedLinesOfSight)} lines of sight found so far\n')
    print('########################################\n')

# %%
validatedLinesOfSight
