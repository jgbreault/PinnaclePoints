# %%
import pandas as pd
import commons as me

# %%
summitFile = f'../data/clean/summits_prm.csv'
prominenceThreshold = 500 # in m
distanceThreshold = 200*1000 # in m

summits = pd.read_csv(summitFile)

# %%
len(summits)
# Out:
# 11866676

# %%
summits = summits.query('prominence > @prominenceThreshold')
len(summits)
# Out:
# 55444

# %%
# Find all points beyond the prominence threshold
# Find all distinct pairs of point that are in MHD range but beyond the distance threshold

# Remove all that don't pass the mid point test, do this in batches of 100
# Remove all that don't have LOS

# %%
numSummits = len(summits)

candidateLinesOfSight = []
for i, observer in enumerate(summits.itertuples()):
    
    if i%100 == 99:
        print(f'Found {len(candidateLinesOfSight)} lines of sight candidates in {i+1}/{numSummits} summits')

    targets = summits.iloc[i+1:]
    for target in targets.itertuples():

        obs = me.Summit(summitId = observer.summitId,
                        latitude = observer.latitude, 
                        longitude = observer.longitude, 
                        elevation = observer.elevation)
        
        trg = me.Summit(summitId = target.summitId,
                        latitude = target.latitude, 
                        longitude = target.longitude, 
                        elevation = target.elevation)

        candidateLos = me.LineOfSight(obs, trg)

        if candidateLos.isInPossibleRange() and candidateLos.surfaceDistance > distanceThreshold:
            candidateLinesOfSight.append(candidateLos)

    break

# %%
len(candidateLinesOfSight)
# Out:
# 1058

# %%
for start in range(0, len(candidateLinesOfSight), me.apiRequestLimit):
    losBatch = targets.iloc[start:start + me.apiRequestLimit]

    batchMidLats =
    for los in losBatch:

# %%
print(observer, target)
# Out:
# Pandas(Index=0, summitId=0, latitude=27.9892, longitude=86.9256, elevation=8737.79, prominence=8737.79, candidate=True) Pandas(Index=7960495, summitId=7960495, latitude=62.1878, longitude=-49.6444, elevation=500.49, prominence=500.49, candidate=False)

# %%
print(obs.longitude, obs.latitude, trg.longitude, trg.latitude)

me.geod.npts(obs.longitude, obs.latitude, trg.longitude, trg.latitude, 1)[0]
# Out:
# 86.9256 27.9892 -49.6444 62.1878
# (56.41031475569322, 64.9855690453571)
